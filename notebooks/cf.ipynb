# %%
import pandas as pd
import numpy as np
import scipy.stats
from sklearn.metrics.pairwise import cosine_similarity

# %%
user_df = pd.read_json("../data/MOOCCube/entities/user.json",lines=True)
data_train = []
data_test = []
for index, row in user_df.iterrows():
    user_id = row["id"]
    courses = row["course_order"]
    if len(courses) > 5:

        index_partition = int(len(courses) * 0.75)

        courses_1 = courses[:index_partition]
        courses_2 = courses[index_partition:]
        
        for course in courses_1:
            data_train.append({
                "user_id":user_id,
                "course_id":course,
                "view":1
            })
            
        for course in courses_2:
            data_test.append({
                "user_id":user_id,
                "course_id":course,
                "view":1
            })

# %%
df_train = pd.DataFrame(data_train)
df_test = pd.DataFrame(data_test)

# %%
df_train.shape
# Out:
# (153049, 3)

# %%
matrix = df_train.pivot_table(index='user_id', columns='course_id', values='view')
matrix.head()
# Out:
# course_id   C_course-v1:ACCA+FA1_X+2019_T1  C_course-v1:ACCA+FA1_X+sp  \
# user_id
# U_10000168                             NaN                        NaN
# U_10000205                             NaN                        NaN
# U_10000338                             NaN                        NaN
# U_10000415                             NaN                        NaN
# U_10000491                             NaN                        NaN
#
# course_id   C_course-v1:ACCA+FA1_X_en+2019_T1  C_course-v1:ACCA+FA2_X+2019_T1  \
# user_id
# U_10000168                                NaN                             NaN
# U_10000205                                NaN                             NaN
# U_10000338                                NaN                             NaN
# U_10000415                                NaN                             NaN
# U_10000491                                NaN                             NaN
#
# course_id   C_course-v1:ACCA+FA2_X+sp  C_course-v1:ACCA+FA2_X_en+2019_T1  \
# user_id
# U_10000168                        NaN                                NaN
# U_10000205                        NaN                                NaN
# U_10000338                        NaN                                NaN
# U_10000415                        NaN                                NaN
# U_10000491                        NaN                                NaN
#
# course_id   C_course-v1:ACCA+MA1_X+2019_T1  C_course-v1:ACCA+MA1_X+sp  \
# user_id
# U_10000168                             NaN                        NaN
# U_10000205                             NaN                        NaN
# U_10000338                             NaN                        NaN
# U_10000415                             NaN                        NaN
# U_10000491                             NaN                        NaN
#
# course_id   C_course-v1:ACCA+MA1_X_en+2019_T1  C_course-v1:ACCA+MA2_X+2019_T1  \
# user_id
# U_10000168                                NaN                             NaN
# U_10000205                                NaN                             NaN
# U_10000338                                NaN                             NaN
# U_10000415                                NaN                             NaN
# U_10000491                                NaN                             NaN
#
# course_id   ...  C_course-v1:nxu+2018122711+2019_T1  \
# user_id     ...
# U_10000168  ...                                 NaN
# U_10000205  ...                                 NaN
# U_10000338  ...                                 NaN
# U_10000415  ...                                 NaN
# U_10000491  ...                                 NaN
#
# course_id   C_course-v1:nxu+2018122712+2019_T1  \
# user_id
# U_10000168                                 NaN
# U_10000205                                 NaN
# U_10000338                                 NaN
# U_10000415                                 NaN
# U_10000491                                 NaN
#
# course_id   C_course-v1:nxu+2018122713+2019_T1  \
# user_id
# U_10000168                                 NaN
# U_10000205                                 NaN
# U_10000338                                 NaN
# U_10000415                                 NaN
# U_10000491                                 NaN
#
# course_id   C_course-v1:qdu+2018122608X+2018_T2  \
# user_id
# U_10000168                                  NaN
# U_10000205                                  NaN
# U_10000338                                  NaN
# U_10000415                                  NaN
# U_10000491                                  NaN
#
# course_id   C_course-v1:qhnu+20181212x+2018_T2  \
# user_id
# U_10000168                                 NaN
# U_10000205                                 NaN
# U_10000338                                 NaN
# U_10000415                                 NaN
# U_10000491                                 NaN
#
# course_id   C_course-v1:qhnu+20181212x+2019_T1  \
# user_id
# U_10000168                                 NaN
# U_10000205                                 NaN
# U_10000338                                 NaN
# U_10000415                                 NaN
# U_10000491                                 NaN
#
# course_id   C_course-v1:rcoe+mooc103+2019_T1  \
# user_id
# U_10000168                               NaN
# U_10000205                               NaN
# U_10000338                               NaN
# U_10000415                               NaN
# U_10000491                               NaN
#
# course_id   C_course-v1:shsmu+shsmu001+2019_T1  \
# user_id
# U_10000168                                 NaN
# U_10000205                                 NaN
# U_10000338                                 NaN
# U_10000415                                 NaN
# U_10000491                                 NaN
#
# course_id   C_course-v1:snnu+20180920X+2019_T1  \
# user_id
# U_10000168                                 NaN
# U_10000205                                 NaN
# U_10000338                                 NaN
# U_10000415                                 NaN
# U_10000491                                 NaN
#
# course_id   C_course-v1:xuetangX+MOOC102+2019_T1
# user_id
# U_10000168                                   NaN
# U_10000205                                   NaN
# U_10000338                                   NaN
# U_10000415                                   NaN
# U_10000491                                   NaN
#
# [5 rows x 691 columns]

# %%
matrix = matrix.fillna(0)
matrix.head()
# Out:
# course_id   C_course-v1:ACCA+FA1_X+2019_T1  C_course-v1:ACCA+FA1_X+sp  \
# user_id
# U_10000168                             0.0                        0.0
# U_10000205                             0.0                        0.0
# U_10000338                             0.0                        0.0
# U_10000415                             0.0                        0.0
# U_10000491                             0.0                        0.0
#
# course_id   C_course-v1:ACCA+FA1_X_en+2019_T1  C_course-v1:ACCA+FA2_X+2019_T1  \
# user_id
# U_10000168                                0.0                             0.0
# U_10000205                                0.0                             0.0
# U_10000338                                0.0                             0.0
# U_10000415                                0.0                             0.0
# U_10000491                                0.0                             0.0
#
# course_id   C_course-v1:ACCA+FA2_X+sp  C_course-v1:ACCA+FA2_X_en+2019_T1  \
# user_id
# U_10000168                        0.0                                0.0
# U_10000205                        0.0                                0.0
# U_10000338                        0.0                                0.0
# U_10000415                        0.0                                0.0
# U_10000491                        0.0                                0.0
#
# course_id   C_course-v1:ACCA+MA1_X+2019_T1  C_course-v1:ACCA+MA1_X+sp  \
# user_id
# U_10000168                             0.0                        0.0
# U_10000205                             0.0                        0.0
# U_10000338                             0.0                        0.0
# U_10000415                             0.0                        0.0
# U_10000491                             0.0                        0.0
#
# course_id   C_course-v1:ACCA+MA1_X_en+2019_T1  C_course-v1:ACCA+MA2_X+2019_T1  \
# user_id
# U_10000168                                0.0                             0.0
# U_10000205                                0.0                             0.0
# U_10000338                                0.0                             0.0
# U_10000415                                0.0                             0.0
# U_10000491                                0.0                             0.0
#
# course_id   ...  C_course-v1:nxu+2018122711+2019_T1  \
# user_id     ...
# U_10000168  ...                                 0.0
# U_10000205  ...                                 0.0
# U_10000338  ...                                 0.0
# U_10000415  ...                                 0.0
# U_10000491  ...                                 0.0
#
# course_id   C_course-v1:nxu+2018122712+2019_T1  \
# user_id
# U_10000168                                 0.0
# U_10000205                                 0.0
# U_10000338                                 0.0
# U_10000415                                 0.0
# U_10000491                                 0.0
#
# course_id   C_course-v1:nxu+2018122713+2019_T1  \
# user_id
# U_10000168                                 0.0
# U_10000205                                 0.0
# U_10000338                                 0.0
# U_10000415                                 0.0
# U_10000491                                 0.0
#
# course_id   C_course-v1:qdu+2018122608X+2018_T2  \
# user_id
# U_10000168                                  0.0
# U_10000205                                  0.0
# U_10000338                                  0.0
# U_10000415                                  0.0
# U_10000491                                  0.0
#
# course_id   C_course-v1:qhnu+20181212x+2018_T2  \
# user_id
# U_10000168                                 0.0
# U_10000205                                 0.0
# U_10000338                                 0.0
# U_10000415                                 0.0
# U_10000491                                 0.0
#
# course_id   C_course-v1:qhnu+20181212x+2019_T1  \
# user_id
# U_10000168                                 0.0
# U_10000205                                 0.0
# U_10000338                                 0.0
# U_10000415                                 0.0
# U_10000491                                 0.0
#
# course_id   C_course-v1:rcoe+mooc103+2019_T1  \
# user_id
# U_10000168                               0.0
# U_10000205                               0.0
# U_10000338                               0.0
# U_10000415                               0.0
# U_10000491                               0.0
#
# course_id   C_course-v1:shsmu+shsmu001+2019_T1  \
# user_id
# U_10000168                                 0.0
# U_10000205                                 0.0
# U_10000338                                 0.0
# U_10000415                                 0.0
# U_10000491                                 0.0
#
# course_id   C_course-v1:snnu+20180920X+2019_T1  \
# user_id
# U_10000168                                 0.0
# U_10000205                                 0.0
# U_10000338                                 0.0
# U_10000415                                 0.0
# U_10000491                                 0.0
#
# course_id   C_course-v1:xuetangX+MOOC102+2019_T1
# user_id
# U_10000168                                   0.0
# U_10000205                                   0.0
# U_10000338                                   0.0
# U_10000415                                   0.0
# U_10000491                                   0.0
#
# [5 rows x 691 columns]

# %%
user_correlation = matrix.T.corr(method='pearson', min_periods=1)

# %%
similar_users = user_correlation["U_10000205"].sort_values(ascending=False)[1:11]
df = pd.DataFrame(similar_users)

# %%
df.head()
for index, row in df.iterrows():
    print(row["U_10000205"])
    print(index)
# Out:
# 0.5441271493535857
# U_1966725
# 0.5441271493535855
# U_2013352
# 0.495620437956205
# U_8475699
# 0.4956204379562047
# U_8863612
# 0.49562043795620453
# U_471472
# 0.4273156230155508
# U_1018007
# 0.4040829209128268
# U_36008
# 0.40408292091282677
# U_8550243
# 0.40408292091282677
# U_2576601
# 0.40408292091282677
# U_22772

# %%
user_df.head(

)
# Out:
#            id name                                       course_order  \
# 0   U_7001215  李喜锋  [C_course-v1:TsinghuaX+00740043_2x_2015_T2+sp,...
# 1  U_10402446  五元香  [C_course-v1:TsinghuaX+00510888X+2019_T1, C_co...
# 2  U_10359065   魏珊  [C_course-v1:TsinghuaX+00612642X+sp, C_course-...
# 3   U_7423998  郭海滨  [C_course-v1:TsinghuaX+30240184_2X+sp, C_cours...
# 4    U_545306  李其艳  [C_course-v1:TsinghuaX+20430064_2X+sp, C_cours...
#
#                                          enroll_time
# 0  [2017-05-01 11:07:53, 2017-05-17 10:07:17, 201...
# 1         [2019-06-14 08:50:04, 2019-01-04 20:36:07]
# 2         [2019-01-18 21:19:56, 2019-01-14 21:54:54]
# 3  [2017-08-16 10:38:11, 2018-07-01 18:24:24, 201...
# 4  [2018-09-05 15:40:40, 2019-02-28 10:08:49, 201...

# %%
def make_recomendation(user,dfs,matrix,num_rec=10):
    similar_users = matrix[user].sort_values(ascending=False)[1:11]
    df = pd.DataFrame(similar_users)
    similar_users_ids = []
    for index, row in df.iterrows():
        similar_users_ids.append(index)
    # print(similar_users_ids)
    courses_taken=dfs.loc[dfs['id'] == user, 'course_order'].iloc[0]
    recomendation = {}
    for user_id in similar_users_ids:
        result = dfs.loc[dfs['id'] == user_id, 'course_order'].iloc[0]
        set1 = set(courses_taken)
        set2 = set(result)
        courses_not_taken = set1-set2
        for j in courses_not_taken:
            cant = recomendation.get(j,0)
            recomendation[j]=cant+1
    final = []
    for i in recomendation:
        final.append({
            "course_id":i,
            "quantity":recomendation[i]
        })
    sorted_data = sorted(final, key=lambda x: x['quantity'])[::-1]
    print(sorted_data)
        
make_recomendation("U_10000205",user_df,user_correlation)
# Out:
# [{'course_id': 'C_course-v1:GZHU+20180718001+2019_T1', 'quantity': 10}, {'course_id': 'C_course-v1:TsinghuaX+60240013X+sp', 'quantity': 10}, {'course_id': 'C_course-v1:UST+UST001+sp', 'quantity': 10}, {'course_id': 'C_course-v1:NCTU+wghx+2017_T1', 'quantity': 9}, {'course_id': 'C_course-v1:TsinghuaX+30240184+sp', 'quantity': 9}, {'course_id': 'C_course-v1:TsinghuaX+70660542X+2015_T2', 'quantity': 6}, {'course_id': 'C_course-v1:TsinghuaX+30240243X+sp', 'quantity': 4}, {'course_id': 'C_course-v1:TsinghuaX+30150153X+sp', 'quantity': 3}, {'course_id': 'C_course-v1:TsinghuaX+70150023X+sp', 'quantity': 2}]
